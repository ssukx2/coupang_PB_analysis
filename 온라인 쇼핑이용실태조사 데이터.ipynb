# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
shopping = pd.read_csv('C:/Users/attac/OneDrive/바탕 화면/김수인/T아카데미/T아카데미/최종 데이터/최종 데이터/shopping.csv')

# %%
shopping.head()
# Out:
#        구분    전체    남성    여성   20대   30대   40대   50대
# 0      식품  65.5  62.7  66.9  60.9  64.7  68.7  66.8
# 1   의류/패션  58.8  50.8  63.1  67.5  57.6  57.0  52.8
# 2    생활용품  46.7  42.7  48.8  34.8  41.0  54.2  59.5
# 3  화장품/향수  19.9  10.1  25.2  24.9  21.6  16.2  16.8
# 4    농수산물  17.9  15.1  19.4   9.4  15.0  19.6  31.6

# %%
help(pd.DataFrame.plot)
# Out:
# Help on class PlotAccessor in module pandas.plotting._core:
#
# class PlotAccessor(pandas.core.base.PandasObject)
#  |  PlotAccessor(data) -> 'None'
#  |
#  |  Make plots of Series or DataFrame.
#  |
#  |  Uses the backend specified by the
#  |  option ``plotting.backend``. By default, matplotlib is used.
#  |
#  |  Parameters
#  |  ----------
#  |  data : Series or DataFrame
#  |      The object for which the method is called.
#  |  x : label or position, default None
#  |      Only used if data is a DataFrame.
#  |  y : label, position or list of label, positions, default None
#  |      Allows plotting of one column versus another. Only used if data is a
#  |      DataFrame.
#  |  kind : str
#  |      The kind of plot to produce:
#  |
#  |      - 'line' : line plot (default)
#  |      - 'bar' : vertical bar plot
#  |      - 'barh' : horizontal bar plot
#  |      - 'hist' : histogram
#  |      - 'box' : boxplot
#  |      - 'kde' : Kernel Density Estimation plot
# ...

# %%
shopping.plot(kind='bar')
# Out:
# <Axes: >
# C:\Users\attac\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\attac\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\attac\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\attac\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\attac\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터
categories = ["전체", "남성", "여성", "20대", "30대", "40대", "50대"]
items = ["식품", "의류/패션", "생활용품", "화장품/향수", "농수산물", "아동/유아용품", "여행(숙박/항공)", 
         "가전/전자제품", "서적", "사무/문구", "컴퓨터 및 주변기기", "스포츠/레저용품", "게임/소프트웨어", 
         "아이돌굿즈/음반", "애견용품"]

# 데이터 배열
data = np.array([
    [65.5, 62.7, 66.9, 60.9, 64.7, 68.7, 66.8],
    [58.8, 50.8, 63.1, 67.5, 57.6, 57.0, 52.8],
    [46.7, 42.7, 48.8, 34.8, 41.0, 54.2, 59.5],
    [19.9, 10.1, 25.2, 24.9, 21.6, 16.2, 16.8],
    [17.9, 15.1, 19.4, 9.4, 15.0, 19.6, 31.6],
    [8.6, 5.8, 10.1, 2.4, 15.0, 9.7, 1.9],
    [8.0, 8.1, 7.9, 8.0, 11.3, 5.6, 5.7],
    [7.4, 16.8, 2.3, 6.1, 5.2, 8.7, 11.1],
    [5.9, 7.5, 5.0, 3.8, 3.2, 9.3, 7.6],
    [5.2, 4.8, 5.3, 7.5, 6.0, 3.3, 3.8],
    [4.6, 10.8, 1.2, 4.5, 4.3, 4.6, 5.4],
    [4.6, 9.8, 1.8, 3.1, 4.3, 4.9, 6.6],
    [2.9, 3.8, 2.3, 9.4, 1.9, 0.8, 0.0],
    [2.1, 1.3, 2.5, 4.9, 1.7, 1.6, 0.0],
    [0.6, 1.0, 0.3, 0.0, 0.3, 1.0, 0.9]
])

# 시각화
plt.figure(figsize=(12, 8))

# 막대 그래프
bar_width = 0.35
index = np.arange(len(categories) - 1)  # 20대부터 50대까지

for i, item in enumerate(items):
    plt.bar(index + i * bar_width, data[i][3:], bar_width, label=item)

plt.xlabel('성별/연령')
plt.ylabel('구매 비율 (%)')
plt.title('성별/연령별 생활용품 구매 비율')
plt.xticks(index + bar_width * (len(items) - 1) / 2, categories[3:])
plt.legend(loc='upper right')

# 히트맵
plt.figure(figsize=(10, 6))
plt.imshow(data[:, 3:], cmap='YlGnBu', aspect='auto')
plt.colorbar(label='구매 비율 (%)')
plt.xticks(np.arange(len(categories) - 3), categories[3:])
plt.yticks(np.arange(len(items)), items)
plt.title('성별/연령별 생활용품 구매 비율 (히트맵)')
plt.xlabel('연령')
plt.ylabel('카테고리')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 37
#      34 index = np.arange(len(categories) - 1)  # 20대부터 50대까지
#      36 for i, item in enumerate(items):
# ---> 37     plt.bar(index + i * bar_width, data[i][3:], bar_width, label=item)
#      39 plt.xlabel('성별/연령')
#      40 plt.ylabel('구매 비율 (%)')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2742, in bar(x, height, width, bottom, align, data, **kwargs)
#    2731 @_copy_docstring_and_deprecators(Axes.bar)
#    2732 def bar(
#    2733     x: float | ArrayLike,
#    (...)
#    2740     **kwargs,
#    2741 ) -> BarContainer:
# -> 2742     return gca().bar(
#    2743         x,
#    2744         height,
#    2745         width=width,
#    2746         bottom=bottom,
#    2747         align=align,
#    2748         **({"data": data} if data is not None else {}),
#    2749         **kwargs,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 데이터
categories = ["전체", "남성", "여성", "20대", "30대", "40대", "50대"]
items = ["식품", "의류/패션", "생활용품", "화장품/향수", "농수산물", "아동/유아용품", "여행(숙박/항공)", 
         "가전/전자제품", "서적", "사무/문구", "컴퓨터 및 주변기기", "스포츠/레저용품", "게임/소프트웨어", 
         "아이돌굿즈/음반", "애견용품"]

# 데이터 배열
data = np.array([
    [65.5, 62.7, 66.9, 60.9, 64.7, 68.7, 66.8],
    [58.8, 50.8, 63.1, 67.5, 57.6, 57.0, 52.8],
    [46.7, 42.7, 48.8, 34.8, 41.0, 54.2, 59.5],
    [19.9, 10.1, 25.2, 24.9, 21.6, 16.2, 16.8],
    [17.9, 15.1, 19.4, 9.4, 15.0, 19.6, 31.6],
    [8.6, 5.8, 10.1, 2.4, 15.0, 9.7, 1.9],
    [8.0, 8.1, 7.9, 8.0, 11.3, 5.6, 5.7],
    [7.4, 16.8, 2.3, 6.1, 5.2, 8.7, 11.1],
    [5.9, 7.5, 5.0, 3.8, 3.2, 9.3, 7.6],
    [5.2, 4.8, 5.3, 7.5, 6.0, 3.3, 3.8],
    [4.6, 10.8, 1.2, 4.5, 4.3, 4.6, 5.4],
    [4.6, 9.8, 1.8, 3.1, 4.3, 4.9, 6.6],
    [2.9, 3.8, 2.3, 9.4, 1.9, 0.8, 0.0],
    [2.1, 1.3, 2.5, 4.9, 1.7, 1.6, 0.0],
    [0.6, 1.0, 0.3, 0.0, 0.3, 1.0, 0.9]
])

# 데이터 전치
# data_transposed = data.transpose()

# %%
data_transposed
# Out:
# array([[65.5, 58.8, 46.7, 19.9, 17.9,  8.6,  8. ,  7.4,  5.9,  5.2,  4.6,
#          4.6,  2.9,  2.1,  0.6],
#        [62.7, 50.8, 42.7, 10.1, 15.1,  5.8,  8.1, 16.8,  7.5,  4.8, 10.8,
#          9.8,  3.8,  1.3,  1. ],
#        [66.9, 63.1, 48.8, 25.2, 19.4, 10.1,  7.9,  2.3,  5. ,  5.3,  1.2,
#          1.8,  2.3,  2.5,  0.3],
#        [60.9, 67.5, 34.8, 24.9,  9.4,  2.4,  8. ,  6.1,  3.8,  7.5,  4.5,
#          3.1,  9.4,  4.9,  0. ],
#        [64.7, 57.6, 41. , 21.6, 15. , 15. , 11.3,  5.2,  3.2,  6. ,  4.3,
#          4.3,  1.9,  1.7,  0.3],
#        [68.7, 57. , 54.2, 16.2, 19.6,  9.7,  5.6,  8.7,  9.3,  3.3,  4.6,
#          4.9,  0.8,  1.6,  1. ],
#        [66.8, 52.8, 59.5, 16.8, 31.6,  1.9,  5.7, 11.1,  7.6,  3.8,  5.4,
#          6.6,  0. ,  0. ,  0.9]])

# %%
data_transposed[0][3:]
# Out:
# array([19.9, 17.9,  8.6,  8. ,  7.4,  5.9,  5.2,  4.6,  4.6,  2.9,  2.1,
#         0.6])

# %%
# 시각화
plt.figure(figsize=(12, 8))

# 막대 그래프
bar_width = 0.1
index = np.arange(len(categories) - 1)  # 20대부터 50대까지

# %%
help(plt.bar)
# Out:
# Help on function bar in module matplotlib.pyplot:
#
# bar(x: 'float | ArrayLike', height: 'float | ArrayLike', width: 'float | ArrayLike' = 0.8, bottom: 'float | ArrayLike | None' = None, *, align: "Literal['center', 'edge']" = 'center', data=None, **kwargs) -> 'BarContainer'
#     Make a bar plot.
#
#     The bars are positioned at *x* with the given *align*\ment. Their
#     dimensions are given by *height* and *width*. The vertical baseline
#     is *bottom* (default 0).
#
#     Many parameters can take either a single value applying to all bars
#     or a sequence of values, one for each bar.
#
#     Parameters
#     ----------
#     x : float or array-like
#         The x coordinates of the bars. See also *align* for the
#         alignment of the bars to the coordinates.
#
#     height : float or array-like
#         The height(s) of the bars.
#
#         Note that if *bottom* has units (e.g. datetime), *height* should be in
# ...

# %%
# for i, item in enumerate(items):
    # plt.bar(index + i * bar_width, data_transposed[i][3:], bar_width, label=item)
    plt.bar(index + i * bar_width, data_transposed[3])
    plt.xlabel('성별/연령')
    plt.ylabel('구매 비율 (%)')
    plt.title('성별/연령별 생활용품 구매 비율')
    plt.xticks(index + bar_width * (len(items) - 1) / 2, categories[3:])
    plt.legend(loc='upper right')
    
    plt.tight_layout()
    plt.show()
# Out:
#   Cell In[29], line 3
#     plt.bar(index + i * bar_width,, data_transposed[3])
#     ^
# IndentationError: unexpected indent
